# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import mglearn

# %%
X,y = make_moons(n_samples=100, noise=0.25,random_state=3)
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify = y,random_state=42)
forest = RandomForestClassifier(n_estimators = 5, random_state = 2)
forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=None,
#             oob_score=False, random_state=2, verbose=0, warm_start=False)

# %%
fig,axes = plt.subplots(2,3,figsize=(20,10))
for i,(ax,tree) in enumerate(zip(axes.ravel(),forest.estimators_)):
    ax.set_title("Tree{}".format(i))
    mglearn.plots.plot_tree_partition(X_train,y_train,tree,ax=ax)
mglearn.plots.plot_2d_separator(forest,X_train,fill=True,ax=axes[-1,-1],alpha=.4)
axes[-1,-1].set_title("RandomForet")
mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train)

# %%
print("Accuracy on trainning set:{:.3f}".format(forest.score(X_train,y_train)))
# Out:
# Accuracy on trainning set:0.960

# %%
print("Accuracy on trainning set:{:.3f}".format(forest.score(X_test,y_test)))
# Out:
# Accuracy on trainning set:0.920

# %%
forest2 = RandomForestClassifier(n_estimators=10,random_state=2)
forest2.fit(X_train,y_train)
print("Model two Accuracy on trainning set:{:.3f}".format(forest2.score(X_train,y_train)))
print("Model two Accuracy on trainning set:{:.3f}".format(forest2.score(X_test,y_test)))
# Out:
# Model two Accuracy on trainning set:0.960
# Model two Accuracy on trainning set:0.920

# %%
forest3 = RandomForestClassifier(max_features=1,random_state=2)
forest3.fit(X_train,y_train)
print("Model two Accuracy on trainning set:{:.3f}".format(forest3.score(X_train,y_train)))
print("Model two Accuracy on trainning set:{:.3f}".format(forest3.score(X_test,y_test)))
# Out:
# Model two Accuracy on trainning set:0.960
# Model two Accuracy on trainning set:0.920
# /usr/lib64/python3.6/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print(X)
# Out:
# [[ 1.87756309  0.56839425]
#  [ 0.36877983 -0.34894509]
#  [ 0.96515318  0.10921819]
#  [ 0.48599685  0.20291313]
#  [ 1.72532644  0.53367598]
#  [ 1.47976586  0.08726406]
#  [ 2.11889248  0.60498388]
#  [-0.74017805  0.49615542]
#  [-0.38099245  1.34740194]
#  [ 0.22944941  0.87981305]
#  [ 1.31311917 -0.69665985]
#  [ 0.87435391  0.83750547]
#  [ 0.77145295 -0.69709227]
#  [ 1.26285558  0.12916271]
#  [-0.71988634  0.69106791]
#  [ 0.79205253 -0.40516241]
#  [ 1.31886119 -0.41396289]
#  [ 0.26579093  0.78151982]
#  [ 0.08686038  0.49400243]
#  [-0.74872343 -0.06972957]
#  [ 0.88404174 -0.35425773]
#  [ 1.02671711  0.73292915]
#  [ 0.73867317  0.30808589]
#  [ 1.12856036  0.33191968]
#  [ 1.15536561 -0.50593577]
#  [ 1.56825139 -0.05911358]
#  [ 0.29004812  1.00820293]
#  [ 0.64076308 -0.19860992]
#  [-1.20034998  0.46412528]
#  [-0.16955317  0.60660877]
#  [-0.53369875  0.50244086]
#  [ 1.00549331  0.38686701]
#  [ 0.65294065  0.80929512]
#  [-0.56688607  0.73004641]
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
grbt = GradientBoostingClassifier(random_state=0)
grbt.fit(X_train,y_train)
print("Model two Accuracy on trainning set:{:.3f}".format(grbt.score(X_train,y_train)))
print("Model two Accuracy on trainning set:{:.3f}".format(grbt.score(X_test,y_test)))
# Out:
# Model two Accuracy on trainning set:1.000
# Model two Accuracy on trainning set:0.880

# %%
from sklearn.ensemble import GradientBoostingClassifier
grbt = GradientBoostingClassifier(random_state=0,max_depth=1)
grbt.fit(X_train,y_train)
print("Model two Accuracy on trainning set:{:.3f}".format(grbt.score(X_train,y_train)))
print("Model two Accuracy on trainning set:{:.3f}".format(grbt.score(X_test,y_test)))
# Out:
# Model two Accuracy on trainning set:0.973
# Model two Accuracy on trainning set:0.840

# %%
from sklearn.ensemble import GradientBoostingClassifier
grbt = GradientBoostingClassifier(random_state=0,learning_rate=0.01)
grbt.fit(X_train,y_train)
print("Model two Accuracy on trainning set:{:.3f}".format(grbt.score(X_train,y_train)))
print("Model two Accuracy on trainning set:{:.3f}".format(grbt.score(X_test,y_test)))
# Out:
# Model two Accuracy on trainning set:0.907
# Model two Accuracy on trainning set:0.880

# %%
from sklearn.ensemble import GradientBoostingClassifier
grbt = GradientBoostingClassifier(random_state=0,learning_rate=0.001)
grbt.fit(X_train,y_train)
print("Model two Accuracy on trainning set:{:.3f}".format(grbt.score(X_train,y_train)))
print("Model two Accuracy on trainning set:{:.3f}".format(grbt.score(X_test,y_test)))
# Out:
# Model two Accuracy on trainning set:0.893
# Model two Accuracy on trainning set:0.880

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators=10,random_state=2)
ada.fit(X_train,y_train)
print("Model two Accuracy on trainning set:{:.3f}".format(ada.score(X_train,y_train)))
print("Model two Accuracy on trainning set:{:.3f}".format(ada.score(X_test,y_test)))
# Out:
# Model two Accuracy on trainning set:1.000
# Model two Accuracy on trainning set:0.880

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_= AdaBoostClassifier(n_estimators=1000,random_state=2)
ada_.fit(X_train,y_train)
print("Model two Accuracy on trainning set:{:.3f}".format(ada_.score(X_train,y_train)))
print("Model two Accuracy on trainning set:{:.3f}".format(ada_.score(X_test,y_test)))
# Out:
# Model two Accuracy on trainning set:1.000
# Model two Accuracy on trainning set:0.840

# %%
fig,axes = plt.subplots(4,3,figsize=(20,10))
for i,(ax,tree) in enumerate(zip(axes.ravel(),ada.estimators_)):
    ax.set_title("Tree{}".format(i))
    mglearn.plots.plot_tree_partition(X_train,y_train,tree,ax=ax)
mglearn.plots.plot_2d_separator(ada,X_train,fill=True,ax=axes[-1,-1],alpha=.4)
axes[-1,-1].set_title("adaboost")
mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train)
